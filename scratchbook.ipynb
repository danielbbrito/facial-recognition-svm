# %%
import argparse

parser = argparse.ArgumentParser()
parser.parse_args()
# Out:
# usage: ipykernel_launcher.py [-h]
# ipykernel_launcher.py: error: unrecognized arguments: --f=/home/daniel/.vscode-server/data/User/globalStorage/ms-toolsai.jupyter/version-2025.9.1/jupyter/runtime/kernel-v3edf02d9fa1ac32b3a51c8aca4487fe59fd744326.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /home/daniel/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
